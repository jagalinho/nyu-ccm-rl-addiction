# %% [markdown]
# # Experiments

# %%
#imports
import numpy as np
import addiction_agent as aa

# %%
cost_agent = aa.AddictionAgent(max_time = 10, n_trials = 50, ETA=1, GAMMA=.5, rewards=[(10, 4)], substances=[(5,.5,8,(0,5))], verbose=False)

# %%
cost_agent = cost_agent.add_substance(1, .5, 8, (5,10))
cost_agent = cost_agent.add_substance(-1, .5, 8, (10,49))

# %%
cost_agent.run_TD()

# %%
aa.plot_comparison(cost_agent.value, cost_agent.prediction_error, "Cost Experiment", 'Value', 'Prediction Error')

# %%
cost_agent2 = aa.AddictionAgent(max_time = 10, n_trials = 50, ETA=1, GAMMA=.5, rewards=[(10, 4)], substances=[(5,.5,8,(0,2))], verbose=False)
cost_agent2 = cost_agent2.add_substance(4.5, .5, 8, (1,2))
cost_agent2 = cost_agent2.add_substance(4, .5, 8, (2,3))
cost_agent2 = cost_agent2.add_substance(3.5, .5, 8, (3,4))
cost_agent2 = cost_agent2.add_substance(3, .5, 8, (4,5))
cost_agent2 = cost_agent2.add_substance(2.5, .5, 8, (5,6))
cost_agent2 = cost_agent2.add_substance(2, .5, 8, (6,7))
cost_agent2 = cost_agent2.add_substance(1.5, .5, 8, (7,8))
cost_agent2 = cost_agent2.add_substance(1, .5, 8, (8,9))
cost_agent2 = cost_agent2.add_substance(.5, .5, 8, (9,10))
cost_agent2 = cost_agent2.add_substance(-10, .5, 8, (10,49))
cost_agent2.run_TD()

# %%
aa.plot_comparison(cost_agent2.value, cost_agent2.prediction_error, "Cost Experiment", 'Value', 'Prediction Error')

# %%
cost_agent3 = aa.AddictionAgent(max_time = 10, n_trials = 50, ETA=1, GAMMA=.5, rewards=[(10, 4)], substances=[(-5,.5,8, (0,10))], verbose=False)
cost_agent3 = cost_agent3.add_substance(5, .5, 8, (10,49))

cost_agent3.run_TD()

# %%
aa.plot_comparison(cost_agent3.value, cost_agent3.prediction_error, "Cost Experiment", 'Value', 'Prediction Error')

# %%
cost_agent4 = aa.AddictionAgent(max_time = 10, n_trials = 50, ETA=1, GAMMA=.5, rewards=[], substances=[(5,.5,8)], verbose=False)
#cost_agent4 = cost_agent.add_substance(5, .5, 8, (10,49))

cost_agent4.run_TD()

# %%
aa.plot_comparison(cost_agent4.value, cost_agent4.prediction_error, "Addiction", 'Value', 'Prediction Error')

# %%
cost_agent4 = aa.AddictionAgent(max_time = 10, n_trials = 50, ETA=1, GAMMA=.5, rewards=[(10,8)], substances=[], verbose=False)
cost_agent4.run_TD()
aa.plot_comparison(cost_agent4.value, cost_agent4.prediction_error, "No Addiction", 'Value', 'Prediction Error')

# %%
cost_agent4.plot_value('V')
# Out:
# No handles with labels found to put in legend.
